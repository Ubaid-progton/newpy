# %%
import requests
from bs4 import BeautifulSoup
# import pandas as pd
f = []
for x in range(1,16):
    base_url="https://www.europages.co.uk"
    url =f"https://www.europages.co.uk/companies/manufacturer%20producer/pg-{x}/cosmetics%20manufacturing.html"
    def ds(url_name):
        r = requests.get(url_name)
        return BeautifulSoup(r.content,"lxml")
    soup = ds(url)
    company = soup.find_all('header',{"class":"ep-ecard__top-actions"})
    print(url)


    for i in company:
        name = i.find('p').text.strip().replace('\n','')
        links = base_url + i.a['href']
        s2 = ds(links)
        country = s2.find('p',class_="ma-0").text
        add = s2.find('div',class_="v-card__text").find('p',class_="ma-0").text
        f.append([name,links,country,add])
#     print(f)
# df = pd.DataFrame(f,columns=["Company Name","Website","Country","Address"])
# # print(df)
# df.to_csv("euro.csv")
# Out:
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-1/cosmetics%20manufacturing.html
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-2/cosmetics%20manufacturing.html
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-3/cosmetics%20manufacturing.html
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-4/cosmetics%20manufacturing.html
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-5/cosmetics%20manufacturing.html
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-6/cosmetics%20manufacturing.html
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-7/cosmetics%20manufacturing.html
# https://www.europages.co.uk/companies/manufacturer%20producer/pg-8/cosmetics%20manufacturing.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-e2693e581c77> in <module>
#      17         name = i.find('p').text.strip().replace('\n','')
#      18         links = base_url + i.a['href']
# ---> 19         s2 = ds(links)
#      20         country = s2.find('p',class_="ma-0").text
#      21         add = s2.find('div',class_="v-card__text").find('p',class_="ma-0").text
#
# <ipython-input-19-e2693e581c77> in ds(url_name)
#       7     url =f"https://www.europages.co.uk/companies/manufacturer%20producer/pg-{x}/cosmetics%20manufacturing.html"
#       8     def ds(url_name):
# ----> 9         r = requests.get(url_name)
#      10         return BeautifulSoup(r.content,"lxml")
#      11     soup = ds(url)
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497                     decode_content=False,
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#     501
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /home/ubaidullah/snap/jupyter/common/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# /snap/jupyter/6/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /snap/jupyter/6/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /snap/jupyter/6/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /snap/jupyter/6/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /snap/jupyter/6/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# /snap/jupyter/6/lib/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
