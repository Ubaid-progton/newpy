# %%
import requests
from bs4 import BeautifulSoup
f =[]

base_url = "https://www.pr.com"
url = "https://www.pr.com/business-directory/1074"

def ds(url_name):
    r = requests.get(url_name)
    return BeautifulSoup(r.content,"lxml")
soup = ds(url)
companies = soup.find_all('h3',{"class":"listing__title"})
for i in companies:
    name = i.text.strip()
    link = base_url + i.find('a')['href']
    s2 = ds(link)
#     about = s2.find('div',class_="profile__body").find('dl',{"class":"profile__info-table"}).text.replace('\n','')
    ab1 = s2.find('dl',{"class":"profile__info-table"}).find('div',{'class':"profile__info-row"})
    print(ab.text.replace('\n',' '))
    ab2 = s2.find('dl',{"class":"profile__info-table"}).find('div',{'class':"profile__info-row"})
    print(ab2.text)
# Out:
#  Status                Private Company
#
# Status
#
#               Private Company
#
#
#
#
#
#  Status                Private Company
#
# Status
#
#               Private Company
#
#
#
#
#
#  Status                Private Company
#
# Status
#
#               Private Company
#
#
#
#
#
#  Status                Private Company
#
# Status
#
#               Private Company
#
#
#
#
#
#  Status                Private Company
#
# Status
#
#               Private Company
#
#
#
#
#
#  Status                Private Company
#
# Status
#
#               Private Company
#
#
#
#
#
#  Status                Private Company
#
# Status
#
#               Private Company
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-fff9b4cd9f3f> in <module>
#      14     name = i.text.strip()
#      15     link = base_url + i.find('a')['href']
# ---> 16     s2 = ds(link)
# ...

# %%
url_1= ds("https://www.pr.com/business-directory/1074")
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="index,follow" name="robots"/>
# <meta content="Find Health Care businesses with full company profiles in the PR.com Business Directory. Find press releases, products, services and more." name="description"/>
# <meta content="Health Care Business Directory - PR.com" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="Find Health Care businesses with full company profiles in the PR.com Business Directory. Find press releases, products, services and more." property="og:description"/>
# <meta content="PR.com" property="og:site_name"/>
# <meta content="https://www.pr.com/images/PRcom-Logo-OG.jpg" property="og:image"/>
# ...
